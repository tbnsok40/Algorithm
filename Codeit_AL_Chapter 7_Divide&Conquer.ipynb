# %% [markdown]
# ## Divide and Conquer의 단계
#
# 1. divide: 부분 문제로 분할
# 2. conquer: 부분 문제를 푼다는 의미 (정복)
# 3. combine: 부분 문제로 원 문제를 해결

# %% [markdown]
# ### 1부터 n까지의 합

# %%
def consecutive_sum(start, end):
    
    
    if start == end:
         return start
    
    else:
        mid = (start + end) // 2

        return consecutive_sum(start, mid)



        
        
# 테스트
print(consecutive_sum(1, 2))
# print(consecutive_sum(1, 100))
# print(consecutive_sum(1, 253))
# print(consecutive_sum(1, 388))

# %% [markdown]
# # Just 합병

# %%
def merge(list1, list2):
    merge_list = []   
    
    while (list1 == []) or (list2 == []):

        
        
        elif (list1 == []):
            merge_list.append(list2[0])
            return merge_list

        elif list2 == []:
            merge_list.append(list1[0])
            return merge_list
        
        else:
            return merge_list
    
    if list1[0] < list2[0]:
        merge_list.append(list1[0])
        return merge(list1[1:], list2)
    
    else:
        merge_list.append(list2[0])
        return merge(list1, list2[1:])

    
        
    

 
#     if list1[0] < list2[0]:
#         merge_list.append(list1[0])
#         return merge(list1[1:], list2)
#     else:
#         merge_list.append(list2[0])
#         return merge(list1, list2[1:])


print(merge([],[]))
print(merge([1],[]))
print(merge([],[1]))
print(merge([2],[1]))
# print(merge([1, 2, 3, 4],[5, 6, 7, 8]))
# print(merge([5, 6, 7, 8],[1, 2, 3, 4]))
# print(merge([4, 7, 8, 9],[1, 3, 6, 10]))

# %%
def merge(list1, list2):
    merge_list = []
    i = 0
    j = 0
    
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merge_list.append(list1[i])
            i +=1
        else:
            merge_list.append(list2[j])
            j +=1
            
    return merge_list
    
    
    if len(list1) == 0:
        merge_list.append(list2[j])
        return merge_list
    
    elif len(list2) == 0:
        merge_list.append(list1[i])
        return merge_list

print(merge([1],[]))
print(merge([],[1]))
print(merge([2],[1]))
print(merge([1, 2, 3, 4],[5, 6, 7, 8]))
print(merge([5, 6, 7, 8],[1, 2, 3, 4]))
print(merge([4, 7, 8, 9],[1, 3, 6, 10]))

# 잘못품, 뭐가 틀린지도 모르겠

# %%
def merge(list1, list2):
    merge_list = []
    i = 0
    j = 0
    
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merge_list.append(list1[i])
            i +=1
        else:
            merge_list.append(list2[j])
            j +=1
            

    
    
    while i >= len(list1) and j < len(list2):
        merge_list.append(list2[j])
        j += 1

        
    while j >= len(list2) and i < len(list1):
        merge_list.append(list1[i])
        i += 1
    
    
    return merge_list




print(merge([1],[]))
print(merge([],[1]))
print(merge([2],[1]))
print(merge([1, 2, 3, 4],[5, 6, 7, 8]))
print(merge([5, 6, 7, 8],[1, 2, 3, 4]))
print(merge([4, 7, 8, 9],[1, 3, 6, 10]))


# 내가 푼 것

# %%
# 코드잇 해설
def merge(list1, list2):
    i = 0
    j = 0

    # 정렬된 항목들을 담을 리스트
    merged_list = []

    # list1과 list2를 돌면서 merged_list에 항목 정렬
    while i < len(list1) and j < len(list2):
        if list1[i] > list2[j]:
            merged_list.append(list2[j])
            j += 1
        else:
            merged_list.append(list1[i])
            i += 1

    # list2에 남은 항목이 있으면 정렬 리스트에 추가
    if i == len(list1):
        merged_list += list2[j:]

    # list1에 남은 항목이 있으면 정렬 리스트에 추가
    elif j == len(list2):
        merged_list += list1[i:]

    return merged_list

# 테스트
print(merge([1],[]))
print(merge([],[1]))
print(merge([2],[1]))
print(merge([1, 2, 3, 4],[5, 6, 7, 8]))
print(merge([5, 6, 7, 8],[1, 2, 3, 4]))
print(merge([4, 7, 8, 9],[1, 3, 6, 10]))

# %% [markdown]
# # 합병 정렬 구현

# %%
def merge(list1, list2):
    i = 0
    j = 0

    # 정렬된 항목들을 담을 리스트
    merged_list = []

    # list1과 list2를 돌면서 merged_list에 항목 정렬
    while i < len(list1) and j < len(list2):
        if list1[i] > list2[j]:
            merged_list.append(list2[j])
            j += 1
        else:
            merged_list.append(list1[i])
            i += 1

    # list2에 남은 항목이 있으면 정렬 리스트에 추가
    if i == len(list1):
        merged_list += list2[j:]

    # list1에 남은 항목이 있으면 정렬 리스트에 추가
    elif j == len(list2):
        merged_list += list1[i:]

    return merged_list


# 합병 정렬
def merge_sort(my_list):

    if len(my_list) < 2:
        return my_list
    
    
    # 하나의 리스트를 인자로 받는다.
    # 이걸 나눠야 한다 반으로. 
    # 언제까지?
    # 반으로 나눈 리스트의 순서를 상관하지 않도록, 아예 길이가 1인 원소로 나눠버린다.
    # 그걸 merge함수의 인자로 넣어버린다.
    # merge함수 작동
    # Boom bamm
    
    mid_ind = len(my_list) // 2
    left_half = my_list[:mid_ind]
    right_half = my_list[mid_ind:]
    
    merge_sort(left_half)
    merge_sort(right_half)
    
    return merge(merge_sort(left_half), merge_sort(right_half))
    
        
    
    # when length of each list is 1, merge fucntion initiate.    

# 테스트
print(merge_sort([1, 3, 5, 7, 9, 11, 13, 11]))
print(merge_sort([28, 13, 9, 30, 1, 48, 5, 7, 15]))
print(merge_sort([2, 5, 6, 7, 1, 2, 4, 7, 10, 11, 4, 15, 13, 1, 6, 4]))
# Out:
# [1, 3, 5, 7, 9, 11, 11, 13]
# [1, 5, 7, 9, 13, 15, 28, 30, 48]
# [1, 1, 2, 2, 4, 4, 4, 5, 6, 6, 7, 7, 10, 11, 13, 15]

# %%
lis = [3,5,6,23,8]
lis.sort()
print(lis)

# %% [markdown]
# # Quick Sort

# %% [markdown]
# #### 이 방식이 왜 틀렸냐면, 애초에 설계 단계에서 Pivot_index를 어떻게 구할지 고려가 안돼있기 때문이다.
#
# #### 다시해야한다 ^^ㅠ

# %%
def swap_elements(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp
    return my_list

def partition(my_list, start, end): #end = 6, len(my_list) = 7, for문 i = 0~6
    small = []
    big =[]
    unknown = my_list[start:end]
    
    for i in range(len(my_list)-1):
        if unknown[i] < my_list[end]:
            small.append(unknown[i])

        else:
            big.append(unknown[i])

    big.sort(reverse=True)
    big = big + my_list[end:]
    
    return small + swap_elements(big, 0, len(big)-1)

list1 = [4, 3, 6, 2, 7, 1, 5]
pivot_index1 = partition(list1, 0, len(list1) - 1)
print(list1)
print(pivot_index1)

list2 = [6, 1, 2, 6, 3, 5, 4]
pivot_index2 = partition(list2, 0, len(list2) - 1)
print(list2)
print(pivot_index2)

# %% [markdown]
# ### 제대로 푼 것

# %%
def swap_elements(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp
    return my_list

def partition(my_list, start, end): #end = 6, len(my_list) = 7, for문 i = 0~6
    start = 0 
    for i in range(len(my_list)):
        if my_list[i] < my_list[end]:
            swap_elements(my_list, start, i)
            start += 1
        else:
            continue
    swap_elements(my_list, start, i)
    return start

list1 = [4, 3, 6, 2, 7, 1, 5]
pivot_index1 = partition(list1, 0, len(list1) - 1)
print(list1)
print(pivot_index1)

list2 = [6, 1, 2, 6, 3, 5, 4]
pivot_index2 = partition(list2, 0, len(list2) - 1)
print(list2)
print(pivot_index2)

# %% [markdown]
# ### QuickSort_코드잇 명답 (간결한거 보소)

# %%
# 두 요소의 위치를 바꿔주는 helper function
def swap_elements(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp


# 퀵 정렬에서 사용되는 partition 함수
def partition(my_list, start, end):
    # 리스트 값 확인과 기준점 이하 값들의 위치 확인을 위한 변수 정의
    i = start
    b = start
    p = end

    # 범위안의 모든 값들을 볼 때까지 반복문을 돌린다
    while i < p:
        # i 인덱스의 값이 기준점보다 작으면 i와 b 인덱스에 있는 값들을 교환하고 b를 1 증가 시킨다
        if my_list[i] <= my_list[p]:
            swap_elements(my_list, i, b)
            b += 1
        i += 1

    # b와 기준점인 p 인덱스에 있는 값들을 바꿔준다
    swap_elements(my_list, b, p)
    p = b

    # pivot의 최종 인덱스를 리턴해 준다
    return p


# 테스트 1
list1 = [4, 3, 6, 2, 7, 1, 5]
pivot_index1 = partition(list1, 0, len(list1) - 1)
print(list1)
print(pivot_index1)

# 테스트 2
list2 = [28, 13, 9, 30, 1, 48, 5, 7, 15]
pivot_index2 = partition(list2, 0, len(list2) - 1)
print(list2)
print(pivot_index2)
# Out:
# [4, 3, 2, 1, 5, 6, 7]
# 4
# [13, 9, 1, 5, 7, 15, 30, 28, 48]
# 5

# %%
>>> number2 = input("숫자를 입력하세요: ")
number2

# %% [markdown]
# # 퀵정렬 구현하기
# ### 왜 안돼;

# %%
# 두 요소의 위치를 바꿔주는 helper function
def swap_elements(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp


# 퀵 정렬에서 사용되는 partition 함수
def partition(my_list, start, end):
    # 리스트 값 확인과 기준점 이하 값들의 위치 확인을 위한 변수 정의
    i = start
    b = start
    p = end

    # 범위안의 모든 값들을 볼 때까지 반복문을 돌린다
    while i < p:
        # i 인덱스의 값이 기준점보다 작으면 i와 b 인덱스에 있는 값들을 교환하고 b를 1 증가 시킨다
        if my_list[i] <= my_list[p]:
            swap_elements(my_list, i, b)
            b += 1
        i += 1

    # b와 기준점인 p 인덱스에 있는 값들을 바꿔준다
    swap_elements(my_list, b, p)
    p = b

    # pivot의 최종 인덱스를 리턴해 준다
    return p

## 피벗의 위치(기준점)을 알게 됐으니 이걸 활용해보자. 

# 퀵 정렬
def quicksort(my_list, start, end):
    p = partition(my_list, start, end)
    small = my_list[:p]
    small.sort()
    return small
    

# 테스트 1
# list1 = [1, 3, 5, 7, 9, 11, 13, 11]
# print(quicksort(list1, 0, len(list1) - 1))
# print(list1)

# # 테스트 2
# list2 = [28, 13, 9, 30, 1, 48, 5, 7, 15]
# print(quicksort(list2, 0, len(list2) - 1))
# print(list2)

# 테스트 3
list3 = [2, 5, 6, 7, 1, 2, 4, 7, 10, 11, 4, 15, 13, 1, 6, 4]
print(partition(list3, 0, len(list3) - 1))
print(list3)
print()
print(quicksort(list3, 0, len(list3) - 1))
print(list3)
# Out:
# 6
# [2, 1, 2, 4, 4, 1, 4, 7, 10, 11, 5, 15, 13, 6, 6, 7]
#
# [1, 1, 2, 2, 4, 4, 4, 5, 6, 6, 7]
# [2, 1, 2, 4, 4, 1, 4, 7, 5, 6, 6, 7, 13, 11, 10, 15]

# %% [markdown]
# # Divide & Conquer 로 퀵정렬 구현하기
# ### 야매쓰지 말고

# %%
# 두 요소의 위치를 바꿔주는 helper function
def swap_elements(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp


# 퀵 정렬에서 사용되는 partition 함수
def partition(my_list, start, end):
    # 리스트 값 확인과 기준점 이하 값들의 위치 확인을 위한 변수 정의
    i = start
    b = start
    p = end

    # 범위안의 모든 값들을 볼 때까지 반복문을 돌린다
    while i < p:
        # i 인덱스의 값이 기준점보다 작으면 i와 b 인덱스에 있는 값들을 교환하고 b를 1 증가 시킨다
        if my_list[i] <= my_list[p]:
            swap_elements(my_list, i, b)
            b += 1
        i += 1

    # b와 기준점인 p 인덱스에 있는 값들을 바꿔준다
    swap_elements(my_list, b, p)
    p = b

    # pivot의 최종 인덱스를 리턴해 준다
    return b

## 피벗의 위치(기준점)을 알게 됐으니 이걸 활용해보자. 

# 퀵 정렬
def quicksort(my_list, start, end):
    if start >= end: #if the length of the list is 0
        return
    else:
        pivot = partition(my_list, start, end)
        quicksort(my_list, start, pivot-1) #pivot기준 왼쪽
        quicksort(my_list,pivot+1, end) #pivot기준 오른쪽
        return my_list

#테스트 1
list1 = [1, 3, 5, 7, 9, 11, 13, 11]
(quicksort(list1, 0, len(list1) - 1))
print(list1)

# 테스트 2
list2 = [28, 13, 9, 30, 1, 48, 5, 7, 15]
(quicksort(list2, 0, len(list2) - 1))
print(list2)

# 테스트 3
list3 = [2, 5, 6, 7, 1, 2, 4, 7, 10, 11, 4, 15, 13, 1, 6, 4]
(quicksort(list3, 0, len(list3) - 1))
print(list3)
# Out:
# [1, 3, 5, 7, 9, 11, 11, 13]
# [1, 5, 7, 9, 13, 15, 28, 30, 48]
# [1, 1, 2, 2, 4, 4, 4, 5, 6, 6, 7, 7, 10, 11, 13, 15]

# %%
def quicksort(list):
    if len(list) <=1:
        return list
    pivot = list[len(list)//2]
    less_arr, equal_arr, big_arr = [],[],[]
    for i in list:
        if i < pivot:
            less_arr.append(i)
        elif i > pivot:
            big_arr.append(i)
        else:
            equal_arr.append(i)
    return quicksort(less_arr) + equal_arr + quicksort(big_arr)


#테스트 1
list = [1, 3, 5, 7, 9, 11, 13, 11]
print(quicksort(list))

#테스트 2
list2 = [28, 13, 9, 30, 1, 48, 5, 7, 15]
print(quicksort(list2))

# 테스트 3
list3 = [2, 5, 6, 7, 1, 2, 4, 7, 10, 11, 4, 15, 13, 1, 6, 4]
print(quicksort(list3))
# Out:
# [1, 3, 5, 7, 9, 11, 11, 13]
# [1, 5, 7, 9, 13, 15, 28, 30, 48]
# [1, 1, 2, 2, 4, 4, 4, 5, 6, 6, 7, 7, 10, 11, 13, 15]

# %%
# 두 요소의 위치를 바꿔주는 helper function
def swap_elements(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp


# 퀵 정렬에서 사용되는 partition 함수
def partition(my_list, start, end):
    # 리스트 값 확인과 기준점 이하 값들의 위치 확인을 위한 변수 정의
    i = start
    b = start
    p = end

    # 범위안의 모든 값들을 볼 때까지 반복문을 돌린다
    while i < p:
        # i 인덱스의 값이 기준점보다 작으면 i와 b 인덱스에 있는 값들을 교환하고 b를 1 증가 시킨다
        if my_list[i] <= my_list[p]:
            swap_elements(my_list, i, b)
            b += 1
        i += 1

    # b와 기준점인 p 인덱스에 있는 값들을 바꿔준다
    swap_elements(my_list, b, p)
    p = b

    # pivot의 최종 인덱스를 리턴해 준다
    return b

## 피벗의 위치(기준점)을 알게 됐으니 이걸 활용해보자. 

# 퀵 정렬
def quicksort(my_list, start=0, end=None):
    
    if end == None:
        end = len(my_list) - 1
    
    if start >= end: #if the length of the list is 0
        return
    else:
        pivot = partition(my_list, start, end)
        quicksort(my_list, start, pivot-1) #pivot기준 왼쪽
        quicksort(my_list, pivot+1, end) #pivot기준 오른쪽
        return my_list

# 테스트 1
list1 = [1, 3, 5, 7, 9, 11, 13, 11]
quicksort(list1) # start, end 파라미터 없이 호출
print(list1)

# 테스트 2
list2 = [28, 13, 9, 30, 1, 48, 5, 7, 15]
quicksort(list2) # start, end 파라미터 없이 호출
print(list2)

# 테스트 3
list3 = [2, 5, 6, 7, 1, 2, 4, 7, 10, 11, 4, 15, 13, 1, 6, 4]
quicksort(list3) # start, end 파라미터 없이 호출
print(list3)
# Out:
# [1, 3, 5, 7, 9, 11, 11, 13]
# [1, 5, 7, 9, 13, 15, 28, 30, 48]
# [1, 1, 2, 2, 4, 4, 4, 5, 6, 6, 7, 7, 10, 11, 13, 15]
